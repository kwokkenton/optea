# %% [markdown]
# # Implementation of van der Horst deconvolution
#
# Attempted implementation of <div class="csl-entry">van der Horst, J., &#38; Kalkman, J. (2016). Image resolution and deconvolution in optical tomography. <i>Optics Express</i>, <i>24</i>(21), 24460. https://doi.org/10.1364/oe.24.024460</div>
#
# Procedure
# 1. Perform FBP reconstruction of sinogram
# 2. Determine parameterisation of PSF (including Gaussian beam parameters)
# 3. Convert image into polar coordinates $(r, \theta)$ by interpolation
#    * Interpl2d only gives you points back on a mesh
# 4. Deconvolve using Lucy-Richardson method

# %% [markdown]
# ## Point Spread Function
# The position-dependent tomographic point spread function (PSF), based on a Gaussian beam model, is
#
# $$PSF(u,v) = \sqrt{\frac{1}{\pi^2a_ua_v}}\exp\bigg(-\bigg[\frac{u^2}{a_u} + \frac{v^2}{a_v}\bigg]\bigg)$$
#
# where
# * $r_0 = \sqrt{x_0^2 + y_0^2}$ where $(x_0, y_0)$ are coordinates of the point object
# * $u$ is the radial and $v$ is the tangential coordinate, shifted to be on the object
# * $a_u = w_0^2/2$
# * $a_v = (w_0^2 + \frac{\lambda^2 r_0^2}{\pi^2w_0^2}) / 2$
#
# * Gaussian beam parameters: $w_0$ is the beam waist and $\lambda$ is the wavelength
#
# In the Gaussian beam tomographic model, the radial spread, quantified by $a_u$ is position invariant, whereas the tangential spread, parameterised by $a_v$ varies. There will be large tangential spread further away from the centre due to the effects of defocusing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import matplotlib
matplotlib.rcParams['image.cmap'] = 'bone'
from scipy.ndimage import rotate

# %%
def PSF(u, v, r0, lamb=550e-9, w0=6e-6):
#     # Define parameters
#     lamb = 550e-9 # wavelength (m)
#     w0 = 6e-6 # Beam waist (m)

    # Coordinates in plane polars
    # r0 = 0 # 
    # theta0 = 0 # Angle from x axis to point

    # Evaluation
    au = w0*w0/2
    av = (w0*w0 + lamb**2*r0**2/(np.pi**2* w0**2)) /2
    prefactor = np.sqrt(1/(np.pi*np.pi*au*av ))
    function = np.exp(-(u**2/au + v**2/av ))
    return prefactor * function

# %% [markdown]
# For a depth-dependent PSF modelled by a Gaussian beam, the depth of field (/focus) is twice the Rayleigh range, i.e.,
#
# $$\textrm{DOF} = 2 \times z_R = 2 \times \frac{\pi w_0^2}{\lambda}$$
#
# $$\Rightarrow w_0 = \sqrt{\frac{z_R \lambda}{\pi}}.$$
#
# Also,
#
# $$z_R = \frac{w_0}{\textrm{NA}} \Rightarrow \textrm{NA} = \frac{w_0}{z_R} = \frac{\lambda}{\pi w_0}.$$
#
# Combining the above expressions gives
#
# $$\textrm{DOF} = \frac{2 \lambda}{\pi (\textrm{NA})^2},$$
#
# which matches the functional form of the first term of the Walls/Inoue&Spring expression.

# %%
LABELFONTSIZE = 20
TITLEFONTSIZE = 22

# %%
fig, axs = plt.subplots(3,3, figsize=(8,8))

u = np.linspace(-300,300,200)*1e-6
v = u.copy()
uu, vv = np.meshgrid(u,v)

xs = np.array([-3, 0,3 ])*1e-3 *np.array([1,1,1])[:,np.newaxis]
ys = xs.copy().T

for i in range(9):
    x = xs.reshape(-1)[i]
    y = ys.reshape(-1)[i] 
    r_0 = np.sqrt(x**2 + y**2)
    # print(r_0)
    ax = axs.reshape(-1)[i]
    angle = np.arctan2(x,y)/np.pi*180
    ax.pcolormesh(vv*1e3,uu*1e3, rotate(PSF(uu,vv, r_0), angle=angle, reshape=False), shading='auto')
#     ax.pcolormesh(vv,uu, rotate(PSF(uu,vv, r_0), angle=angle, reshape=False), shading='auto')
    # ax.set_ylabel('Radial coordinate $u$/ $\mu m$')
    # ax.set_xlabel('Tangential coordinate $v$/ $\mu m$')
axs[0,0].set_title('-3 mm', fontsize=LABELFONTSIZE)
axs[0,1].set_title('0 mm', fontsize=LABELFONTSIZE)
axs[0,2].set_title('+3 mm', fontsize=LABELFONTSIZE)
axs[0,0].set_ylabel('+3 mm', fontsize=LABELFONTSIZE)
axs[1,0].set_ylabel('0 mm', fontsize=LABELFONTSIZE)
axs[2,0].set_ylabel('-3 mm', fontsize=LABELFONTSIZE)
plt.suptitle(f'NA = ?', fontsize=TITLEFONTSIZE)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(3,3, figsize=(8,8))

u = np.linspace(-300,300,500)*1e-6
v = u.copy()
uu, vv = np.meshgrid(u,v)

xs = np.array([-3, 0,3 ])*1e-3 *np.array([1,1,1])[:,np.newaxis]
ys = xs.copy().T

for i in range(9):
    x = xs.reshape(-1)[i]
    y = ys.reshape(-1)[i] 
    r_0 = np.sqrt(x**2 + y**2)
    # print(r_0)
    ax = axs.reshape(-1)[i]
    angle = np.arctan2(x,y)/np.pi*180
    ax.pcolormesh(vv*1e3,uu*1e3, rotate(PSF(uu,vv, r_0, lamb=550e-9, w0=2.11e-6), angle=angle, reshape=False), shading='auto')
#     ax.pcolormesh(vv,uu, rotate(PSF(uu,vv, r_0), angle=angle, reshape=False), shading='auto')
    # ax.set_ylabel('Radial coordinate $u$/ $\mu m$')
    # ax.set_xlabel('Tangential coordinate $v$/ $\mu m$')
axs[0,0].set_title('-3 mm', fontsize=LABELFONTSIZE)
axs[0,1].set_title('0 mm', fontsize=LABELFONTSIZE)
axs[0,2].set_title('+3 mm', fontsize=LABELFONTSIZE)
axs[0,0].set_ylabel('+3 mm', fontsize=LABELFONTSIZE)
axs[1,0].set_ylabel('0 mm', fontsize=LABELFONTSIZE)
axs[2,0].set_ylabel('-3 mm', fontsize=LABELFONTSIZE)
plt.suptitle(f'NA = 0.08', fontsize=TITLEFONTSIZE)
plt.tight_layout()
plt.savefig('tomo_psf_f6.png', transparent=True, dpi=300)
plt.show()

# %%
fig, axs = plt.subplots(3,3, figsize=(8,8))

u = np.linspace(-300,300,500)*1e-6
v = u.copy()
uu, vv = np.meshgrid(u,v)

xs = np.array([-3, 0,3 ])*1e-3 *np.array([1,1,1])[:,np.newaxis]
ys = xs.copy().T

for i in range(9):
    x = xs.reshape(-1)[i]
    y = ys.reshape(-1)[i] 
    r_0 = np.sqrt(x**2 + y**2)
    # print(r_0)
    ax = axs.reshape(-1)[i]
    angle = np.arctan2(x,y)/np.pi*180
    ax.pcolormesh(vv*1e3,uu*1e3, rotate(PSF(uu,vv, r_0, lamb=550e-9, w0=6.03e-6), angle=angle, reshape=False), shading='auto')
#     ax.pcolormesh(vv,uu, rotate(PSF(uu,vv, r_0), angle=angle, reshape=False), shading='auto')
    # ax.set_ylabel('Radial coordinate $u$/ $\mu m$')
    # ax.set_xlabel('Tangential coordinate $v$/ $\mu m$')
axs[0,0].set_title('-3 mm', fontsize=LABELFONTSIZE)
axs[0,1].set_title('0 mm', fontsize=LABELFONTSIZE)
axs[0,2].set_title('+3 mm', fontsize=LABELFONTSIZE)
axs[0,0].set_ylabel('+3 mm', fontsize=LABELFONTSIZE)
axs[1,0].set_ylabel('0 mm', fontsize=LABELFONTSIZE)
axs[2,0].set_ylabel('-3 mm', fontsize=LABELFONTSIZE)
plt.suptitle(f'NA = 0.03', fontsize=TITLEFONTSIZE)
plt.tight_layout()
plt.savefig('tomo_psf_f17.png', transparent=True, dpi=300)
plt.show()

# %%
fig, axs = plt.subplots(3,3, figsize=(8,8))

u = np.linspace(-300,300,500)*1e-6
v = u.copy()
uu, vv = np.meshgrid(u,v)

xs = np.array([-3, 0,3 ])*1e-3 *np.array([1,1,1])[:,np.newaxis]
ys = xs.copy().T

for i in range(9):
    x = xs.reshape(-1)[i]
    y = ys.reshape(-1)[i] 
    r_0 = np.sqrt(x**2 + y**2)
    # print(r_0)
    ax = axs.reshape(-1)[i]
    angle = np.arctan2(x,y)/np.pi*180
    ax.pcolormesh(vv*1e3,uu*1e3, rotate(PSF(uu,vv, r_0, lamb=550e-9, w0=1.59e-5), angle=angle, reshape=False), shading='auto')
#     ax.pcolormesh(vv,uu, rotate(PSF(uu,vv, r_0), angle=angle, reshape=False), shading='auto')
    # ax.set_ylabel('Radial coordinate $u$/ $\mu m$')
    # ax.set_xlabel('Tangential coordinate $v$/ $\mu m$')
axs[0,0].set_title('-3 mm', fontsize=LABELFONTSIZE)
axs[0,1].set_title('0 mm', fontsize=LABELFONTSIZE)
axs[0,2].set_title('+3 mm', fontsize=LABELFONTSIZE)
axs[0,0].set_ylabel('+3 mm', fontsize=LABELFONTSIZE)
axs[1,0].set_ylabel('0 mm', fontsize=LABELFONTSIZE)
axs[2,0].set_ylabel('-3 mm', fontsize=LABELFONTSIZE)
plt.suptitle(f'NA = 0.01', fontsize=TITLEFONTSIZE)
plt.tight_layout()
plt.savefig('tomo_psf_f47.png', transparent=True, dpi=300)
plt.show()

# %% [markdown]
# Units are in microns

# %%
# In radial direction

fig, ax = plt.subplots(1,2, figsize=(10, 3))
ax[0].set_title('Radial PSF (uniform)')
ax[0].plot(u*1e6, PSF(u, 0,0))
ax[0].set_xlabel('')
ax[1].set_title('Tangential PSF (variable)')
ax[1].plot(v*1e6, PSF(0,v,0))
ax[1].plot(v*1e6, PSF(0,v,.5e-3), label='defocus 0.5 mm')
ax[1].plot(v*1e6, PSF(0,v,1e-3), label='defocus 1 mm')

plt.legend()

# %% [markdown]
# ## Coordinate Transforms

# %% [markdown]
# Create test image for reconstruction. Include a centred circle and some straight lines to see whether they are reproducible or not.

# %%
# Generate test image for reconstruction
image = np.zeros((100,100))
image[2,:] = 1
image[-15,:] = 1
image[:,-15] = 1
# plt.imshow(image) 

size = np.shape(image)[0]
x = np.linspace(-size//2, size//2, size)
y = x.copy()
xx, yy = np.meshgrid(x, y)
z = image


z[np.sqrt(xx**2 + yy**2)< 25] = 1
z[np.sqrt(xx**2 + yy**2)< 22] = 0

z[np.sqrt(xx**2 + yy**2)< 15] = 1
z[np.sqrt(xx**2 + yy**2)< 13] = 0
# plt.imshow(z)

# Create interpolant
f = interpolate.interp2d(x, y, z, kind='linear')

# Plot interpolated function
plt.figure(figsize=(4,4))
plt.pcolormesh(x,y, f(x,y), shading='auto')
plt.xlabel('x')
plt.ylabel('y')
# plt.colorbar()
# Out:
# Text(0, 0.5, 'y')

# %%
# Plot interpolated function
xnew = np.linspace(-size//2, size//2, 4*size)
ynew = x.copy()
plt.figure(figsize=(4,4))
plt.pcolormesh(xnew,ynew, f(xnew,ynew), shading='auto')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Transform into plane polars by interpolation
#
# We want a grid where $v/ \theta$ and $u / r$ are evenly sampled.
#
# $$x = r\cos(\theta)$$
# $$y = r\sin(\theta)$$

# %%
# Transform into plane polars (r, theta)
# r goes from 0 to sqrt(x_max**2 + y_max**2)
# theta goes from 0 to 360
r_max = np.sqrt(2)*size/2
r = np.linspace(0, r_max)
theta = np.arange(0,360, 1)/360 * 2*np.pi

# Multiply and broadcast
xs = (r[:, np.newaxis]*np.cos(theta[np.newaxis,:]))
ys = (r[:, np.newaxis]*np.sin(theta[np.newaxis,:]))

xs = xs.flatten()
ys = ys.flatten()

result = np.zeros(len(ys))
for i in range(len(xs)):
    result[i]= f(xs[i], ys[i])

plt.pcolormesh(theta,r ,result.reshape((50,360)), shading='auto')
plt.colorbar()
plt.xlabel('Tangential coordinate $v$')
plt.ylabel('Radial coordinate $u$')
# Out:
# Text(0, 0.5, 'Radial coordinate $u$')

# %% [markdown]
# Interpolate result

# %%
# Create interpolant
g = interpolate.interp2d(theta,r, result.reshape((50,360)), kind='linear')

# %% [markdown]
# Transform back to Cartesian coordinates
#
# We want an even sampling of $x$ and $y$.
# $$u = \sqrt{x^2 + y^2} $$
# $$v = \arctan \bigg(\frac{y}{x}\bigg)$$

# %%
us = np.sqrt(x[np.newaxis,:]**2 + y[:, np.newaxis]**2)
vs = np.arctan2(y[:, np.newaxis], x[np.newaxis,:]) + np.pi

us = us.flatten()
vs = vs.flatten()

result_cartesian = np.zeros(len(us))
for i in range(len(us)):
    result_cartesian[i]= g(vs[i], us[i])

# %%
# Plot interpolated function
plt.figure(figsize=(4,4))
plt.xlabel('x')
plt.ylabel('y')

plt.pcolormesh(x,y, result_cartesian.reshape((100,100)),  shading='auto')

# %% [markdown]
# It is possible to c

# %%
# From https://jenda.hrach.eu/f2/cat-py/phantom.py
def phantom (n = 256, p_type = 'Modified Shepp-Logan', ellipses = None):
	"""
	 phantom (n = 256, p_type = 'Modified Shepp-Logan', ellipses = None)
	
	Create a Shepp-Logan or modified Shepp-Logan phantom.

	A phantom is a known object (either real or purely mathematical) 
	that is used for testing image reconstruction algorithms.  The 
	Shepp-Logan phantom is a popular mathematical model of a cranial
	slice, made up of a set of ellipses.  This allows rigorous 
	testing of computed tomography (CT) algorithms as it can be 
	analytically transformed with the radon transform (see the 
	function `radon').
	
	Inputs
	------
	n : The edge length of the square image to be produced.
	
	p_type : The type of phantom to produce. Either 
	  "Modified Shepp-Logan" or "Shepp-Logan".  This is overridden
	  if `ellipses' is also specified.
	
	ellipses : Custom set of ellipses to use.  These should be in 
	  the form
	  	[[I, a, b, x0, y0, phi],
	  	 [I, a, b, x0, y0, phi],
	  	 ...]
	  where each row defines an ellipse.
	  I : Additive intensity of the ellipse.
	  a : Length of the major axis.
	  b : Length of the minor axis.
	  x0 : Horizontal offset of the centre of the ellipse.
	  y0 : Vertical offset of the centre of the ellipse.
	  phi : Counterclockwise rotation of the ellipse in degrees,
	        measured as the angle between the horizontal axis and 
	        the ellipse major axis.
	  The image bounding box in the algorithm is [-1, -1], [1, 1], 
	  so the values of a, b, x0, y0 should all be specified with
	  respect to this box.
	
	Output
	------
	P : A phantom image.
	
	Usage example
	-------------
	  import matplotlib.pyplot as pl
	  P = phantom ()
	  pl.imshow (P)
	
	References
	----------
	Shepp, L. A.; Logan, B. F.; Reconstructing Interior Head Tissue 
	from X-Ray Transmissions, IEEE Transactions on Nuclear Science,
	Feb. 1974, p. 232.
	
	Toft, P.; "The Radon Transform - Theory and Implementation", 
	Ph.D. thesis, Department of Mathematical Modelling, Technical 
	University of Denmark, June 1996.
	
	"""
	
	if (ellipses is None):
		ellipses = _select_phantom (p_type)
	elif (np.size (ellipses, 1) != 6):
		raise AssertionError ("Wrong number of columns in user phantom")
	
	# Blank image
	p = np.zeros ((n, n))

	# Create the pixel grid
	ygrid, xgrid = np.mgrid[-1:1:(1j*n), -1:1:(1j*n)]

	for ellip in ellipses:
		I   = ellip [0]
		a2  = ellip [1]**2
		b2  = ellip [2]**2
		x0  = ellip [3]
		y0  = ellip [4]
		phi = ellip [5] * np.pi / 180  # Rotation angle in radians
		
		# Create the offset x and y values for the grid
		x = xgrid - x0
		y = ygrid - y0
		
		cos_p = np.cos (phi) 
		sin_p = np.sin (phi)
		
		# Find the pixels within the ellipse
		locs = (((x * cos_p + y * sin_p)**2) / a2 
              + ((y * cos_p - x * sin_p)**2) / b2) <= 1
		
		# Add the ellipse intensity to those pixels
		p [locs] += I

	return p


def _select_phantom (name):
	if (name.lower () == 'shepp-logan'):
		e = _shepp_logan ()
	elif (name.lower () == 'modified shepp-logan'):
		e = _mod_shepp_logan ()
	else:
		raise ValueError ("Unknown phantom type: %s" % name)
	
	return e


def _shepp_logan ():
	#  Standard head phantom, taken from Shepp & Logan
	return [[   2,   .69,   .92,    0,      0,   0],
	        [-.98, .6624, .8740,    0, -.0184,   0],
	        [-.02, .1100, .3100,  .22,      0, -18],
	        [-.02, .1600, .4100, -.22,      0,  18],
	        [ .01, .2100, .2500,    0,    .35,   0],
	        [ .01, .0460, .0460,    0,     .1,   0],
	        [ .02, .0460, .0460,    0,    -.1,   0],
	        [ .01, .0460, .0230, -.08,  -.605,   0],
	        [ .01, .0230, .0230,    0,  -.606,   0],
	        [ .01, .0230, .0460,  .06,  -.605,   0]]

def _mod_shepp_logan ():
	#  Modified version of Shepp & Logan's head phantom, 
	#  adjusted to improve contrast.  Taken from Toft.
	return [[   1,   .69,   .92,    0,      0,   0],
	        [-.80, .6624, .8740,    0, -.0184,   0],
	        [-.20, .1100, .3100,  .22,      0, -18],
	        [-.20, .1600, .4100, -.22,      0,  18],
	        [ .10, .2100, .2500,    0,    .35,   0],
	        [ .10, .0460, .0460,    0,     .1,   0],
	        [ .10, .0460, .0460,    0,    -.1,   0],
	        [ .10, .0460, .0230, -.08,  -.605,   0],
	        [ .10, .0230, .0230,    0,  -.606,   0],
	        [ .10, .0230, .0460,  .06,  -.605,   0]]

# %% [markdown]
# ## Deconvolution
#
# We use the Lucy-Richardson method of deconvolution.
# * First proposed in William Hadley Richardson, "Bayesian-Based Iterative Method of Image Restoration*," J. Opt. Soc. Am. 62, 55-59 (1972)
# * The algorithm is based on maximizing the likelihood that the resulting image J is an instance of the original image I under Poisson statistics. (MATLAB site)
#
# Implementation details
# * van der Horst and Kalkman performed the deconvolution for 100 iterations.
# * According to The image can be successively deconvolved in the radial and angular direction using deconvolu-tion (e.g., with the Lucy–Richardson algorithm)

# %%
def interpolate_square(z, width):
    # 
    # Interpolate square image z
    size = np.shape(z)[0]
    x = np.linspace(-width/2, width/2, size)
    y = x.copy()

    f = interpolate.interp2d(x, y, z, kind='linear')
    return f

phantom_size = 256
P = phantom(n= phantom_size)
# plt.imshow(P)
# plt.show()

width = 1e-3
interpolated_phantom = interpolate_square(P, width=width)

# Plot interpolated function
xnew = np.linspace(-1e-3/2, 1e-3/2, 4*phantom_size)
ynew = xnew.copy()

plt.figure(figsize=(4,4))
plt.pcolormesh(xnew, ynew, interpolated_phantom(xnew, ynew), shading='auto')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
def cartesian_to_polars(f, r, theta):
    # Transform into plane polars (r, theta)
    # r goes from 0 to sqrt(x_max**2 + y_max**2)
    # theta goes from 0 to 360

    # Multiply and broadcast
    xs = (r[:, np.newaxis]*np.cos(theta[np.newaxis,:]))
    ys = (r[:, np.newaxis]*np.sin(theta[np.newaxis,:]))

    xs = xs.flatten()
    ys = ys.flatten()

    result = np.zeros(len(ys))
    for i in range(len(xs)):
        result[i]= f(xs[i], ys[i])
    return result
    
num = 256
num_rs = num//2
num_angles = int(np.floor(np.pi*num))

r_max = width/2 #* np.sqrt(2) # Sample only to edge
r = np.linspace(0, r_max, num_rs)
theta = np.linspace(0,360, num_angles)/360 * 2*np.pi

result = cartesian_to_polars(interpolated_phantom, r, theta)
plt.pcolormesh(theta,r ,result.reshape((num_rs,num_angles)), shading='auto')
plt.colorbar()
plt.xlabel('Tangential coordinate $v$')
plt.ylabel('Radial coordinate $u/ m $')
# Out:
# Text(0, 0.5, 'Radial coordinate $u/ m $')

# %% [markdown]
# Want to deconvolve each direction separately.
#
# The tangential direction is much trickier than the radial direction, becauase we need to sample things adequately.

# %%
# Make radial psf given on r spacing previously
psf_size = 11

dr = r[1] - r[0]
u = np.arange(0, psf_size*dr,dr) - psf_size//2*dr
# Ensure that psf sums to 1
radial_psf = PSF(u, 0,0) / np.sum(PSF(u, 0,0))

# Visualise psf
plt.plot(u, radial_psf)
plt.xlabel('Radial coordinate u / m')
plt.ylabel('psf magnitude')
plt.grid()

# Generate and plot 2D psf
radial_psf_2d = np.zeros((psf_size, psf_size))
radial_psf_2d[:, psf_size//2] = radial_psf

# %%
psf_size//2
# Out:
# 5

# %%
# Out:
# 5.0

# %%
psf_size/2
# Out:
# 5.5

# %%
psf = np.zeros((11, 11))
psf[:,5] = radial_psf

# %%
radial_psf
# Out:
# array([2.34170485e-10, 5.43652164e-07, 2.25505419e-04, 1.67124354e-02,
#        2.21293877e-01, 5.23535276e-01, 2.21293877e-01, 1.67124354e-02,
#        2.25505419e-04, 5.43652164e-07, 2.34170485e-10])

# %%
from skimage import color, data, restoration

# Deconvolution in radial direction
# deconvolved_RL = restoration.richardson_lucy(astro_noisy, psf, num_iter=30)

# Deconvolution in tangential direction
# Will liekly involve some coordinate transform

# %%
psf[:,2]=1

# %%
from scipy.signal import convolve2d as conv2

rng = np.random.default_rng()

astro = color.rgb2gray(data.astronaut())

psf = np.zeros((11, 11))
psf[:,5] = radial_psf
astro = conv2(astro, psf, 'same')
# Add Noise to Image
astro_noisy = astro.copy()
astro_noisy += (rng.poisson(lam=25, size=astro.shape) - 10) / 255.

# Restore Image using Richardson-Lucy algorithm
deconvolved_RL = restoration.richardson_lucy(astro_noisy, psf, num_iter=30)

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(8, 5))
plt.gray()

for a in (ax[0], ax[1], ax[2]):
       a.axis('off')

ax[0].imshow(astro)
ax[0].set_title('Original Data')

ax[1].imshow(astro_noisy)
ax[1].set_title('Noisy data')

ax[2].imshow(deconvolved_RL, vmin=astro_noisy.min(), vmax=astro_noisy.max())
ax[2].set_title('Restoration using\nRichardson-Lucy')


fig.subplots_adjust(wspace=0.02, hspace=0.2,
                    top=0.9, bottom=0.05, left=0, right=1)
plt.show()

# %% [markdown]
# To do
#
# * Do inverse transform to verify code.
# * Deconvolution may just be 1D in the thing, so it technically isn't 2D?

# %%
def catesian_to_polar(array):
    # Input: square array
    # Need to resample
    # Output: 
    return
