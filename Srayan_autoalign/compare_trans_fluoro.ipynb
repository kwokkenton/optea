# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
from skimage.transform import iradon
import gc # garbage collection to manage ram usage
from srayan_autoalign import *
import matplotlib.animation as animation
from ipywidgets import *

# %%
fluorescence = io.imread('../../data_store/2022-12-01 broken phantom/1_1_MMStack_Pos0-resized.ome.tif')
plot_alignment(fluorescence)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 130/130 [00:00<00:00, 816.63it/s]

# %%
fluorescence_aligned = apply_offset(fluorescence)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [00:00<00:00, 1055.40it/s]

# %%
# reconstructed = recon(fluorescence_aligned)
# np.save('fluorescence_aligned_reconstructed', reconstructed)

# %%
reconstructed = np.load('fluorescence_aligned_reconstructed.npy')
disp_slices(reconstructed)

# %%
fig = plt.figure()

slice = 0

anim_img = plt.imshow(reconstructed[0], cmap="gray")

def updatefig(*args):
    global slice
    slice += 1
    anim_img.set_array(reconstructed[slice])
    return anim_img,

ani = animation.FuncAnimation(fig, updatefig, interval=50, blit=True)
display(HTML(ani.to_html5_video()))
# Out:
# HTML(value='<video width="432" height="288" controls autoplay loop>\n  <source type="video/mp4" src="data:vide…

# %%
del reconstructed
gc.collect()
# Out:
# 9552

# %%
transmission = io.imread('../../data_store/2022-12-01 broken phantom/1_2_MMStack_Pos0-resized.ome.tif')
plot_alignment(transmission)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 130/130 [00:00<00:00, 794.18it/s]

# %%
transmission_aligned = apply_offset(transmission)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [00:00<00:00, 1094.53it/s]

# %%
# reconstructed = recon(transmission)
# np.save('transmission_reconstructed', reconstructed)

# %%
reconstructed = np.load('transmission_reconstructed.npy')
disp_slices(reconstructed)

# %%
fig = plt.figure()

slice = 0

anim_img = plt.imshow(reconstructed[0], cmap="gray")

def updatefig(*args):
    global slice
    slice += 1
    anim_img.set_array(reconstructed[slice])
    return anim_img,

ani = animation.FuncAnimation(fig, updatefig, interval=50, blit=True)
display(HTML(ani.to_html5_video()))
# Out:
# HTML(value='<video width="432" height="288" controls autoplay loop>\n  <source type="video/mp4" src="data:vide…

# %%
del reconstructed
gc.collect()
# Out:
# 17984

# %%
# reconstructed = recon(transmission_aligned)
# np.save('transmission_aligned_reconstructed', reconstructed)

# %%
reconstructed = np.load('transmission_aligned_reconstructed.npy')
disp_slices(reconstructed)
del reconstructed
gc.collect()
# Out:
# 9557
